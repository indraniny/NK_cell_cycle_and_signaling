# %% [markdown]
# This is to check non-monotonic peak case in Fig. 4 in paper Date: Dec 27, 2024

# %%
import matplotlib.pyplot as plt
import numpy as np
r=20
delta=0.5
kcat=10000.0
rd=36.0
kon=10.0
koff=3000.0

Etot=r/delta
kd=(koff+kcat+delta)/kon
alpha=kcat/(delta+rd)
beta=(1+alpha)
C1=(Etot*Etot)/(((1+beta)*Etot)+kd)
C2=(Etot*Etot)/(((1+beta)*Etot)+(1.3*kd))
C3=(Etot*Etot)/(((1+beta)*Etot)+(1.6*kd))
C4=(Etot*Etot)/(((1+beta)*Etot)+(2.0*kd))


C = [C1,C2,C3,C4]
P=[alpha*c for c in C]


print(f'Etot and Stot = {Etot}')
print(f'kd = {kd}')
print(f'alpha = {alpha}')

print(f'Complex (approx.) = {C}')
print(f'Product (approx.) = {P}')

print('from formula')
Et=[3.6791e+01, 3.9142e+01, 3.9788e+01, 3.9742e+01]
St=[3.6715e+01, 3.9328e+01, 3.9969e+01, 4.0148e+01]
C1=(Et[0]*St[0])/((St[0]+beta*Et[0])+kd)
C2=(Et[1]*St[1])/((St[1]+beta*Et[1])+(1.3*kd))
C3=(Et[2]*St[2])/((St[2]+beta*Et[2])+(1.6*kd))
C4=(Et[3]*St[3])/((St[3]+beta*Et[3])+(2.0*kd))


C_formula = [C1,C2,C3,C4]
P_formula=[alpha*c for c in C_formula]
print(f'Complex (approx.) = {C_formula}')
print(f'Product (approx.) = {P_formula}')


c1=((St[0]+beta*Et[0]+kd)-np.sqrt((St[0]+beta*Et[0]+kd)**2-(4*beta*Et[0]*St[0])))/(2*beta)
c2=((St[1]+beta*Et[1]+1.3*kd)-np.sqrt((St[1]+beta*Et[1]+1.3*kd)**2-(4*beta*Et[1]*St[1])))/(2*beta)
c3=((St[2]+beta*Et[2]+1.6*kd)-np.sqrt((St[2]+beta*Et[2]+1.6*kd)**2-(4*beta*Et[2]*St[2])))/(2*beta)
c4=((St[3]+beta*Et[3]+2.0*kd)-np.sqrt((St[3]+beta*Et[3]+2.0*kd)**2-(4*beta*Et[3]*St[3])))/(2*beta)
C_actual = [c1,c2,c3,c4]
P_actual=[alpha*c for c in C_actual]
print(f'Complex (exact) = {C_actual}')
print(f'Product (exact) = {P_actual}')
exact_product_diff=max(P_actual)-min(P_actual)
print(f'Exact product variation= {exact_product_diff}')



# Set global font settings
plt.rcParams.update({
    'font.family': 'Arial',  # Use Arial font
    'font.size': 16,         # Set font size
})
# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size) 

# Data for plotting
labels = ['G1', 'S', 'G2', 'M']
avg_first_column = [1.1576e-01, 1.2220e-01, 1.2013e-01, 9.3941e-02]
std_first_column = [3.2208e-03, 5.6729e-03, 7.2630e-03, 1.2935e-02]

# Plotting with error bars (standard deviation)
plt.errorbar(labels, avg_first_column, yerr=std_first_column, fmt='o', label='Simulation', 
             capsize=5, linestyle='-', color='red')
plt.plot(labels,C_formula, 's-',label='Approximated formula',color='maroon')
plt.plot(labels,C_actual, 'o-',label='Exact formula',color='maroon')
# Adding labels and title
#plt.xlabel('Labels')
#plt.ylabel('avg. protein/cell')
plt.title('Complex')
plt.legend()
plt.show()

# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size) 

# Data for plotting
labels = ['G1', 'S', 'G2', 'M']
avg_first_column = [3.2319e+01, 3.3765e+01, 3.3360e+01, 3.2176e+01]
std_first_column = [1.2179e-01, 1.0067e-01, 1.4126e-01, 2.8839e-01]
# Plotting with error bars (standard deviation)
plt.errorbar(labels, avg_first_column, yerr=std_first_column, fmt='o', label='Simulation', 
             capsize=5, linestyle='-', color='cyan')
plt.plot(labels,P_formula, 's-',color='blue',label='Approximated formula')
plt.plot(labels,P_actual, 'o-',color='blue',label='exact formula')

# Adding labels and title
#plt.xlabel('Labels')
#plt.ylabel('avg. protein/cell')
plt.title('Product')
plt.legend()
plt.show()
# Out:
# Etot and Stot = 40.0
# kd = 1300.05
# alpha = 273.972602739726
# Complex (approx.) = [0.1296706338146264, 0.1256975318444823, 0.1219606630082366, 0.11731061792664933]
# Product (approx.) = [35.52620104510312, 34.43767995739241, 33.41388027622921, 32.13989532236968]
# from formula
# Complex (approx.) = [0.1179383832310085, 0.1232253367486855, 0.1217615881409814, 0.11759560860673036]
# Product (approx.) = [32.31188581671466, 33.760366232516574, 33.359339216707234, 32.217974960748045]
# Complex (exact) = [0.1182742288751285, 0.12356139158192254, 0.12207533558048023, 0.117877204651756]
# Product (exact) = [32.403898321953015, 33.85243604984179, 33.445297419309654, 32.29512456212493]
# Exact product variation= 1.5573114877168592

# %% [markdown]
# This is to check monotonic decay case in Fig. 4 in paper Date: Dec 27, 2024

# %%
import matplotlib.pyplot as plt
import numpy as np

r=20
delta=0.9
kcat=10000.0
rd=36.0
kon=5.0
koff=5000.0

Etot=r/delta
kd=(koff+kcat+delta)/kon
alpha=kcat/(delta+rd)
beta=(1+alpha)
C1=(Etot*Etot)/(((1+beta)*Etot)+kd)
C2=(Etot*Etot)/(((1+beta)*Etot)+(1.3*kd))
C3=(Etot*Etot)/(((1+beta)*Etot)+(1.6*kd))
C4=(Etot*Etot)/(((1+beta)*Etot)+(2.0*kd))


C = [C1,C2,C3,C4]
P=[alpha*c for c in C]


print(f'Etot and Stot = {Etot}')
print(f'kd = {kd}')
print(f'alpha = {alpha}')

print(f'Complex (approx.) = {C}')
print(f'Product (approx.) = {P}')

print('from formula')
Et=[2.1175e+01, 2.2073e+01, 2.2387e+01, 2.2097e+01]
St=[2.1195e+01, 2.2247e+01, 2.2305e+01, 2.2957e+01]
C1=(Et[0]*St[0])/((St[0]+beta*Et[0])+kd)
C2=(Et[1]*St[1])/((St[1]+beta*Et[1])+(1.3*kd))
C3=(Et[2]*St[2])/((St[2]+beta*Et[2])+(1.6*kd))
C4=(Et[3]*St[3])/((St[3]+beta*Et[3])+(2.0*kd))


C_formula = [C1,C2,C3,C4]
P_formula=[alpha*c for c in C_formula]
print(f'Complex (approx.) = {C_formula}')
print(f'Product (approx.) = {P_formula}')


c1=((St[0]+beta*Et[0]+kd)-np.sqrt((St[0]+beta*Et[0]+kd)**2-(4*beta*Et[0]*St[0])))/(2*beta)
c2=((St[1]+beta*Et[1]+1.3*kd)-np.sqrt((St[1]+beta*Et[1]+1.3*kd)**2-(4*beta*Et[1]*St[1])))/(2*beta)
c3=((St[2]+beta*Et[2]+1.6*kd)-np.sqrt((St[2]+beta*Et[2]+1.6*kd)**2-(4*beta*Et[2]*St[2])))/(2*beta)
c4=((St[3]+beta*Et[3]+2.0*kd)-np.sqrt((St[3]+beta*Et[3]+2.0*kd)**2-(4*beta*Et[3]*St[3])))/(2*beta)
C_actual = [c1,c2,c3,c4]
P_actual=[alpha*c for c in C_actual]
print(f'Complex (exact) = {C_actual}')
print(f'Product (exact) = {P_actual}')
exact_product_diff=max(P_actual)-min(P_actual)
print(f'Exact product variation= {exact_product_diff}')


# Set global font settings
plt.rcParams.update({
    'font.family': 'Arial',  # Use Arial font
    'font.size': 16,         # Set font size
})

# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size) 

# Data for plotting
labels = ['G1', 'S', 'G2', 'M']
avg_first_column = [4.6525e-02, 4.8217e-02, 4.0118e-02, 3.4471e-02]
std_first_column = [3.1150e-03, 3.9275e-03, 4.6005e-03, 1.2083e-02]

# Plotting with error bars (standard deviation)
plt.errorbar(labels, avg_first_column, yerr=std_first_column, fmt='o', label='Simulation', 
             capsize=5, linestyle='-', color='red')
plt.plot(labels,C_formula, 's-',label='Approximated formula',color='maroon')
plt.plot(labels,C_actual, 'o-',label='Exact formula',color='maroon')
# Adding labels and title
#plt.xlabel('Labels')
#plt.ylabel('avg. protein/cell')
plt.title('Complex')
plt.legend()
plt.show()


# Data for plotting
labels = ['G1', 'S', 'G2', 'M']
avg_first_column = [1.3749e+01, 1.3252e+01, 1.2228e+01, 1.1424e+01]
std_first_column = [6.4366e-02, 6.8019e-02, 8.1658e-02, 1.3896e-01]

# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size) 


# Plotting with error bars (standard deviation)
plt.errorbar(labels, avg_first_column, yerr=std_first_column, fmt='o', label='Simulation', 
             capsize=5, linestyle='-', color='cyan')
plt.plot(labels,P_formula, 's-',color='blue',label='Approximated formula')
plt.plot(labels,P_actual, 'o-',color='blue',label='exact formula')

# Adding labels and title
#plt.xlabel('Labels')
#plt.ylabel('avg. protein/cell')
plt.title('Product')
plt.legend()
plt.show()
# Out:
# Etot and Stot = 22.22222222222222
# kd = 3000.18
# alpha = 271.0027100271003
# Complex (approx.) = [0.05446478788330684, 0.049546412990794875, 0.04544276100802804, 0.040923477639320485]
# Product (approx.) = [14.76010511742733, 13.427212192627339, 12.315111384289445, 11.090373343989294]
# from formula
# Complex (approx.) = [0.051110633161501905, 0.049469917431505375, 0.04576116225669096, 0.04215480379844243]
# Product (approx.) = [13.851120097967998, 13.406481688754846, 12.401398985553108, 11.4240660700386]
# Complex (exact) = [0.05119180934171992, 0.04953715992447192, 0.04581348117265601, 0.04219504721163383]
# Product (exact) = [13.873119062796729, 13.424704586577757, 12.415577553565317, 11.43497214407421]
# Exact product variation= 2.438146918722518

# %% [markdown]
# Estimating range of protein variation from the formula  Dat: Dec 29, 2024

# %%
import matplotlib.pyplot as plt
import numpy as np

# r=20 #[18,5350]
# delta=0.5 #[0.03,0.9]
# kcat=10000.0 #[36-7200000]
# rd=36.0 #[36-7200000]
# kon=10.0 #[5-4500]
# koff=3000.0 #[450-7200]

#KD max
r=18 #[18,5350]
delta=0.9 #[0.03,0.9]
kcat=36.0 #[36-7200000]
rd=7200000 #[36-7200000]
kon=4.53 #[5-4500]
koff=7200.0 #[450-7200]

     
Etot=r/delta
kd=(koff+kcat+delta)/kon
alpha=kcat/(delta+rd)
beta=(1+alpha)
C1=(Etot*Etot)/(((1+beta)*Etot)+kd)
C2=(Etot*Etot)/(((1+beta)*Etot)+(1.3*kd))
C3=(Etot*Etot)/(((1+beta)*Etot)+(1.6*kd))
C4=(Etot*Etot)/(((1+beta)*Etot)+(2.0*kd))


C = [C1,C2,C3,C4]
P=[alpha*c for c in C]


print(f'Etot and Stot = {Etot}')
print(f'kd = {kd}')
print(f'alpha = {alpha}')

print(f'Complex (approx.) = {C}')
print(f'Product (approx.) = {P}')

print('from formula')
#Et=[3.6791e+01, 3.9142e+01, 3.9788e+01, 3.9742e+01]
#Etot=30
Et=[Etot,Etot,Etot,Etot]

St=Et
C1=(Et[0]*St[0])/((St[0]+beta*Et[0])+kd)
C2=(Et[1]*St[1])/((St[1]+beta*Et[1])+(1.3*kd))
C3=(Et[2]*St[2])/((St[2]+beta*Et[2])+(1.6*kd))
C4=(Et[3]*St[3])/((St[3]+beta*Et[3])+(2.0*kd))




C_formula = [C1,C2,C3,C4]
P_formula=[alpha*c for c in C_formula]
print(f'Complex (approx.) = {C_formula}')
print(f'Product (approx.) = {P_formula}')
approx_product_diff=max(P_formula)-min(P_formula)
print(f'Approx. product variation= {approx_product_diff}')

c1=((St[0]+beta*Et[0]+kd)-np.sqrt((St[0]+beta*Et[0]+kd)**2-(4*beta*Et[0]*St[0])))/(2*beta)
c2=((St[1]+beta*Et[1]+1.3*kd)-np.sqrt((St[1]+beta*Et[1]+1.3*kd)**2-(4*beta*Et[1]*St[1])))/(2*beta)
c3=((St[2]+beta*Et[2]+1.6*kd)-np.sqrt((St[2]+beta*Et[2]+1.6*kd)**2-(4*beta*Et[2]*St[2])))/(2*beta)
c4=((St[3]+beta*Et[3]+2.0*kd)-np.sqrt((St[3]+beta*Et[3]+2.0*kd)**2-(4*beta*Et[3]*St[3])))/(2*beta)
C_actual = [c1,c2,c3,c4]
P_actual=[alpha*c for c in C_actual]
print(f'Complex (exact) = {C_actual}')
print(f'Product (exact) = {P_actual}')
exact_product_diff=max(P_actual)-min(P_actual)
print(f'Exact product variation= {exact_product_diff}')


# Set global font settings
plt.rcParams.update({
    'font.family': 'Arial',  # Use Arial font
    'font.size': 16,         # Set font size
})

# Access the Axes object

# Data for plotting
labels = ['G1', 'S', 'G2', 'M']
# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size) 

plt.plot(labels,C_formula, 's-',label='approximated formula',color='maroon')
plt.plot(labels,C_actual, 'o-',label='Exact formula',color='maroon')
# Adding labels and title
plt.xlabel('Labels')
#plt.ylabel('avg. protein/cell')
plt.title('Complex')
plt.legend()
plt.show()

# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size) 

plt.plot(labels,P_formula, 's-',color='blue',label='Approximated formula')
plt.plot(labels,P_actual, 'o-',color='blue',label='exact formula')

# Adding labels and title
plt.xlabel('Labels')
#plt.ylabel('avg. protein/cell')
plt.title('Product')
plt.legend()
plt.show()
q_formula=((C1-C4)/C1 *100)
q_actual=((c1-c4)/c1 *100)
print(f' maximum decay is {q_actual}% and {q_formula}%')
# Out:
# Etot and Stot = 20.0
# kd = 1590993.5761589403
# alpha = 195121.9512195122
# Complex (approx.) = [7.281368800492641e-05, 6.699302684362413e-05, 6.203407806918403e-05, 5.646155829144835e-05]
# Product (approx.) = [14.207548879010032, 13.071810115829098, 12.104210354962738, 11.01688942272163]
# from formula
# Complex (approx.) = [7.281368800492641e-05, 6.699302684362413e-05, 6.203407806918403e-05, 5.646155829144835e-05]
# Product (approx.) = [14.207548879010032, 13.071810115829098, 12.104210354962738, 11.01688942272163]
# Approx. product variation= 3.1906594562884028
# Complex (exact) = [7.281387632130885e-05, 6.699317351341418e-05, 6.203419451996728e-05, 5.646164609468944e-05]
# Product (exact) = [14.20758562367002, 13.07183873432472, 12.104233077066787, 11.016906555061356]
# Exact product variation= 3.190679068608665
#  maximum decay is 22.45757409543922% and 22.457494135404474%

# %% [markdown]
# This is to check the monotonic rise case between simulation, exact formula and approximated formual. Date: January 3, 2024

# %%
import matplotlib.pyplot as plt

r=18.0
delta=0.05
kcat=5000.0
rd=36.0
kon=15.0
koff=3000.0

Etot=r/delta
kd=(koff+kcat+delta)/kon
alpha=kcat/(delta+rd)
beta=(1+alpha)
C1=(Etot*Etot)/(((1+beta)*Etot)+kd)
C2=(Etot*Etot)/(((1+beta)*Etot)+(1.3*kd))
C3=(Etot*Etot)/(((1+beta)*Etot)+(1.6*kd))
C4=(Etot*Etot)/(((1+beta)*Etot)+(2.0*kd))


C = [C1,C2,C3,C4]
P=[alpha*c for c in C]


print(f'Etot and Stot = {Etot}')
print(f'kd = {kd}')
print(f'alpha = {alpha}')

print(f'Complex (approx.) = {C}')
print(f'Product (approx.) = {P}')

print('from formula')
Et=[2.1627e+02, 2.5584e+02, 2.7583e+02, 2.8107e+02]
St=[2.1588e+02, 2.5600e+02, 2.7645e+02, 2.8182e+02]
C1=(Et[0]*St[0])/((St[0]+beta*Et[0])+kd)
C2=(Et[1]*St[1])/((St[1]+beta*Et[1])+(1.3*kd))
C3=(Et[2]*St[2])/((St[2]+beta*Et[2])+(1.6*kd))
C4=(Et[3]*St[3])/((St[3]+beta*Et[3])+(2.0*kd))


C_formula = [C1,C2,C3,C4]
P_formula=[alpha*c for c in C_formula]
print(f'Complex (approx.) = {C_formula}')
print(f'Product (approx.) = {P_formula}')

c1=((St[0]+beta*Et[0]+kd)-np.sqrt((St[0]+beta*Et[0]+kd)**2-(4*beta*Et[0]*St[0])))/(2*beta)
c2=((St[1]+beta*Et[1]+1.3*kd)-np.sqrt((St[1]+beta*Et[1]+1.3*kd)**2-(4*beta*Et[1]*St[1])))/(2*beta)
c3=((St[2]+beta*Et[2]+1.6*kd)-np.sqrt((St[2]+beta*Et[2]+1.6*kd)**2-(4*beta*Et[2]*St[2])))/(2*beta)
c4=((St[3]+beta*Et[3]+2.0*kd)-np.sqrt((St[3]+beta*Et[3]+2.0*kd)**2-(4*beta*Et[3]*St[3])))/(2*beta)


C_actual = [c1,c2,c3,c4]
P_actual=[alpha*c for c in C_actual]
print(f'Complex (exact) = {C_actual}')
print(f'Product (exact) = {P_actual}')






# Set global font settings
plt.rcParams.update({
    'font.family': 'Arial',  # Use Arial font
    'font.size': 16,         # Set font size
})

# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size) 

#Plotting complex

# Data for plotting
labels = ['G1', 'S', 'G2', 'M']
avg_first_column = [1.5101e+00, 1.8028e+00, 1.8734e+00, 2.0061e+00]
std_first_column = [5.5417e-02, 8.4091e-02, 9.3127e-02, 2.4236e-01]

# Plotting with error bars (standard deviation)
plt.errorbar(labels, avg_first_column, yerr=std_first_column, fmt='o', label='Simulation', 
             capsize=5, linestyle='-', color='red')
plt.plot(labels,C_formula, 's-',label='Approximated formula',color='maroon')
plt.plot(labels,C_actual, 'o-',label='Exact formula',color='maroon')
# Adding labels and title
#plt.xlabel('Labels')
#plt.ylabel('avg. protein/cell')
plt.title('Complex')
plt.legend()
plt.show()

#Plotting product
# Data for plotting
labels = ['G1', 'S', 'G2', 'M']
avg_first_column = [2.1068e+02, 2.5106e+02, 2.6668e+02, 2.7083e+02]
std_first_column = [2.8695e+00, 3.5187e+00, 3.6462e+00, 7.8157e+00]

# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size) 


# Plotting with error bars (standard deviation)
plt.errorbar(labels, avg_first_column, yerr=std_first_column, fmt='o', label='Simulation', 
             capsize=5, linestyle='-', color='cyan')
plt.plot(labels,P_formula, 's-',color='blue',label='Approximated formula')
plt.plot(labels,P_actual, 'o-',color='blue',label='exact formula')
# Adding labels and title
#plt.xlabel('Labels')
#plt.ylabel('avg. protein/cell')
plt.title('Product')
plt.legend()
plt.show()
# Out:
# Etot and Stot = 360.0
# kd = 533.3366666666667
# alpha = 138.69625520110958
# Complex (approx.) = [2.5320418298601903, 2.524151340078301, 2.516309875090116, 2.505930062787432]
# Product (approx.) = [351.18471981417343, 350.09033842972275, 349.00275660057093, 347.5631155044982]
# from formula
# Complex (approx.) = [1.5079576350587374, 1.7851299765380386, 1.9225658320576025, 1.950392826317399]
# Product (approx.) = [209.1480769845683, 247.59084279307055, 266.6526812839948, 270.51218118133136]
# Complex (exact) = [1.5183595783580714, 1.797431270055, 1.935763970969569, 1.9636561211065462]
# Product (exact) = [210.5907875670002, 249.29698613800278, 268.48321372670864, 272.35175050021445]
